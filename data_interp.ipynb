# %%
import pandas as pd
higgs_data = pd.read_csv('./data/HIGGS.csv.gz', compression='gzip', header=None, nrows=80000)
higgs_data.columns = ['class_label',
                      'lepton_pT', 'lepton_eta', 'lepton_phi',
                      'missing_energy_magnitude', 'missing_energy_phi',
                      'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag',
                      'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag',
                      'jet_3_pt', 'jet_3_eta', 'jet_3_phi', 'jet_3_b-tag',
                      'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag',
                      'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']
drop_feats = False
if drop_feats:
    higgs_data = higgs_data.drop(columns=['m_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb'])

# %%
higgs_data.head(5)
# Out:
#    class_label  lepton_pT  lepton_eta  lepton_phi  missing_energy_magnitude  \
# 0          1.0   0.869293   -0.635082    0.225690                  0.327470
# 1          1.0   0.907542    0.329147    0.359412                  1.497970
# 2          1.0   0.798835    1.470639   -1.635975                  0.453773
# 3          0.0   1.344385   -0.876626    0.935913                  1.992050
# 4          1.0   1.105009    0.321356    1.522401                  0.882808
#
#    missing_energy_phi  jet_1_pt  jet_1_eta  jet_1_phi  jet_1_b-tag  ...  \
# 0           -0.689993  0.754202  -0.248573  -1.092064     0.000000  ...
# 1           -0.313010  1.095531  -0.557525  -1.588230     2.173076  ...
# 2            0.425629  1.104875   1.282322   1.381664     0.000000  ...
# 3            0.882454  1.786066  -1.646778  -0.942383     0.000000  ...
# 4           -1.205349  0.681466  -1.070464  -0.921871     0.000000  ...
#
#    jet_4_eta  jet_4_phi  jet_4_b-tag      m_jj     m_jjj      m_lv     m_jlv  \
# 0  -0.010455  -0.045767     3.101961  1.353760  0.979563  0.978076  0.920005
# 1  -1.138930  -0.000819     0.000000  0.302220  0.833048  0.985700  0.978098
# 2   1.128848   0.900461     0.000000  0.909753  1.108330  0.985692  0.951331
# 3  -0.678379  -1.360356     0.000000  0.946652  1.028704  0.998656  0.728281
# 4  -0.373566   0.113041     0.000000  0.755856  1.361057  0.986610  0.838085
#
#        m_bb     m_wbb    m_wwbb
# 0  0.721657  0.988751  0.876678
# 1  0.779732  0.992356  0.798343
# 2  0.803252  0.865924  0.780118
# 3  0.869200  1.026736  0.957904
# 4  1.133295  0.872245  0.808487
#
# [5 rows x 29 columns]

# %%
higgs_data.describe().T
# Out:
#                             count      mean       std       min       25%  \
# class_label               80000.0  0.530587  0.499067  0.000000  0.000000
# lepton_pT                 80000.0  0.989884  0.561518  0.274697  0.591119
# lepton_eta                80000.0 -0.004118  1.004794 -2.434976 -0.741244
# lepton_phi                80000.0 -0.000180  1.005398 -1.742508 -0.864163
# missing_energy_magnitude  80000.0  0.995104  0.596048  0.001283  0.573856
# missing_energy_phi        80000.0 -0.008862  1.007131 -1.743944 -0.883210
# jet_1_pt                  80000.0  0.987117  0.473301  0.139976  0.676611
# jet_1_eta                 80000.0 -0.003997  1.008712 -2.968735 -0.689225
# jet_1_phi                 80000.0 -0.000549  1.009555 -1.741237 -0.869205
# jet_1_b-tag               80000.0  0.996953  1.027117  0.000000  0.000000
# jet_2_pt                  80000.0  0.991584  0.498866  0.188981  0.657594
# jet_2_eta                 80000.0  0.000641  1.005735 -2.913090 -0.691558
# jet_2_phi                 80000.0  0.002738  1.006190 -1.742372 -0.868515
# jet_2_b-tag               80000.0  1.003240  1.048881  0.000000  0.000000
# jet_3_pt                  80000.0  0.993827  0.489543  0.263608  0.655068
# jet_3_eta                 80000.0 -0.001046  1.008268 -2.729663 -0.698898
# jet_3_phi                 80000.0  0.002487  1.004884 -1.742069 -0.864478
# jet_3_b-tag               80000.0  1.005991  1.195793  0.000000  0.000000
# jet_4_pt                  80000.0  0.986515  0.504898  0.365354  0.617767
# jet_4_eta                 80000.0 -0.005959  1.009233 -2.497265 -0.723351
# jet_4_phi                 80000.0 -0.004397  1.007087 -1.742691 -0.878138
# jet_4_b-tag               80000.0  0.991329  1.395619  0.000000  0.000000
# m_jj                      80000.0  1.033571  0.659606  0.110875  0.790620
# m_jjj                     80000.0  1.023718  0.374598  0.303144  0.846439
# m_lv                      80000.0  1.049889  0.163872  0.133012  0.985779
# m_jlv                     80000.0  1.010679  0.399657  0.319854  0.767188
# m_bb                      80000.0  0.974210  0.524551  0.059529  0.674258
# m_wbb                     80000.0  1.032540  0.365332  0.303350  0.819640
# m_wwbb                    80000.0  0.959770  0.315025  0.350939  0.769977
#
#                                50%       75%        max
# class_label               1.000000  1.000000   1.000000
# lepton_pT                 0.854469  1.235357   7.805887
# lepton_eta               -0.003950  0.735292   2.433894
# lepton_phi                0.003746  0.868220   1.743236
# missing_energy_magnitude  0.890771  1.291671   7.746686
# missing_energy_phi       -0.016084  0.864719   1.743102
# jet_1_pt                  0.892254  1.168358   7.064657
# jet_1_eta                -0.000025  0.681253   2.969674
# jet_1_phi                -0.006317  0.871639   1.741454
# jet_1_b-tag               1.086538  2.173076   2.173076
# jet_2_pt                  0.889005  1.199734   8.280169
# jet_2_eta                 0.002003  0.692650   2.912238
# jet_2_phi                 0.006003  0.874311   1.743175
# jet_2_b-tag               1.107436  2.214872   2.214872
# jet_3_pt                  0.898303  1.222500   8.509908
# jet_3_eta                -0.000737  0.698334   2.730009
# jet_3_phi                 0.003789  0.873059   1.742884
# jet_3_b-tag               0.000000  2.548224   2.548224
# jet_4_pt                  0.870667  1.222391   7.705783
# jet_4_eta                -0.007956  0.712436   2.498009
# jet_4_phi                -0.012472  0.868276   1.743372
# jet_4_b-tag               0.000000  3.101961   3.101961
# m_jj                      0.895380  1.026246  18.428827
# m_jjj                     0.950908  1.083042  10.038273
# m_lv                      0.989732  1.020040   4.565248
# m_jlv                     0.917413  1.142005   7.442589
# m_bb                      0.874280  1.141785  11.994177
# m_wbb                     0.946912  1.139140   7.318191
# m_wwbb                    0.871034  1.058371   6.015647

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Compute the correlation matrix
corr = higgs_data.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Save the plot as an image
plt.savefig('correlation_matrix.png')

# %%
from sklearn.preprocessing import MinMaxScaler

def normalize(df):
    # Columns to be normalized between 0 and 1
    if drop_feats:
        columns_to_normalize_0_1 = ['jet_1_b-tag', 'jet_2_b-tag', 'jet_3_b-tag', 'jet_4_b-tag']
    else:
        columns_to_normalize_0_1 = ['jet_1_b-tag', 'jet_2_b-tag', 'jet_3_b-tag', 'jet_4_b-tag',
                                    'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']    

    # Columns to be normalized between -1 and 1
    columns_to_normalize_minus1_1 = [col for col in df.columns if col not in columns_to_normalize_0_1 + ['class_label']]

    # Separate the data
    data_0_1 = df[columns_to_normalize_0_1]
    data_minus1_1 = df[columns_to_normalize_minus1_1]

    # Apply MinMaxScaler
    scaler_0_1 = MinMaxScaler(feature_range=(0, 1))
    data_0_1 = pd.DataFrame(scaler_0_1.fit_transform(data_0_1), columns=data_0_1.columns)

    scaler_minus1_1 = MinMaxScaler(feature_range=(-1, 1))
    data_minus1_1 = pd.DataFrame(scaler_minus1_1.fit_transform(data_minus1_1), columns=data_minus1_1.columns)

    # Concatenate the dataframes back together
    normalized_df = pd.concat([df['class_label'], data_0_1, data_minus1_1], axis=1)

    # Reorder the columns to match the original dataframe
    normalized_df = normalized_df.reindex(columns=df.columns)

    return normalized_df

normalized_higgs_data = normalize(higgs_data)
normalized_higgs_data.describe().T
# Out:
#                             count      mean       std  min       25%  \
# class_label               80000.0  0.530587  0.499067  0.0  0.000000
# lepton_pT                 80000.0 -0.810073  0.149118 -1.0 -0.915970
# lepton_eta                80000.0 -0.001469  0.412742 -1.0 -0.304261
# lepton_phi                80000.0 -0.000312  0.576863 -1.0 -0.496036
# missing_energy_magnitude  80000.0 -0.743378  0.153910 -1.0 -0.852151
# missing_energy_phi        80000.0 -0.004841  0.577642 -1.0 -0.506325
# jet_1_pt                  80000.0 -0.755327  0.136700 -1.0 -0.845008
# jet_1_eta                 80000.0 -0.001504  0.339725 -1.0 -0.232283
# jet_1_phi                 80000.0 -0.000377  0.579756 -1.0 -0.499219
# jet_1_b-tag               80000.0  0.458775  0.472656  0.0  0.000000
# jet_2_pt                  80000.0 -0.801611  0.123311 -1.0 -0.884167
# jet_2_eta                 80000.0  0.000366  0.345297 -1.0 -0.237285
# jet_2_phi                 80000.0  0.001340  0.577350 -1.0 -0.498582
# jet_2_b-tag               80000.0  0.452956  0.473563  0.0  0.000000
# jet_3_pt                  80000.0 -0.822898  0.118730 -1.0 -0.905058
# jet_3_eta                 80000.0 -0.000447  0.369351 -1.0 -0.256085
# jet_3_phi                 80000.0  0.001194  0.576699 -1.0 -0.496354
# jet_3_b-tag               80000.0  0.394781  0.469265  0.0  0.000000
# jet_4_pt                  80000.0 -0.830756  0.137566 -1.0 -0.931227
# jet_4_eta                 80000.0 -0.002535  0.404075 -1.0 -0.289763
# jet_4_phi                 80000.0 -0.002718  0.577779 -1.0 -0.503995
# jet_4_b-tag               80000.0  0.319581  0.449915  0.0  0.000000
# m_jj                      80000.0  0.050371  0.036009  0.0  0.037108
# m_jjj                     80000.0  0.074018  0.038479  0.0  0.055808
# m_lv                      80000.0  0.206866  0.036973  0.0  0.192401
# m_jlv                     80000.0  0.096989  0.056110  0.0  0.062804
# m_bb                      80000.0  0.076641  0.043952  0.0  0.051508
# m_wbb                     80000.0  0.103950  0.052080  0.0  0.073600
# m_wwbb                    80000.0  0.107478  0.055612  0.0  0.073974
#
#                                50%       75%  max
# class_label               1.000000  1.000000  1.0
# lepton_pT                -0.846034 -0.744885  1.0
# lepton_eta               -0.001400  0.302260  1.0
# lepton_phi                0.001940  0.497946  1.0
# missing_energy_magnitude -0.770318 -0.666799  1.0
# missing_energy_phi       -0.008984  0.496202  1.0
# jet_1_pt                 -0.782725 -0.702981  1.0
# jet_1_eta                -0.000167  0.229281  1.0
# jet_1_phi                -0.003690  0.500493  1.0
# jet_1_b-tag               0.500000  1.000000  1.0
# jet_2_pt                 -0.826966 -0.750159  1.0
# jet_2_eta                 0.000834  0.237952  1.0
# jet_2_phi                 0.003214  0.501448  1.0
# jet_2_b-tag               0.500000  1.000000  1.0
# jet_3_pt                 -0.846065 -0.767437  1.0
# jet_3_eta                -0.000333  0.255752  1.0
# jet_3_phi                 0.001940  0.500811  1.0
# jet_3_b-tag               0.000000  1.000000  1.0
# jet_4_pt                 -0.862321 -0.766489  1.0
# jet_4_eta                -0.003334  0.285095  1.0
# jet_4_phi                -0.007351  0.497946  1.0
# jet_4_b-tag               0.000000  1.000000  1.0
# m_jj                      0.042827  0.049971  1.0
# m_jjj                     0.066539  0.080112  1.0
# m_lv                      0.193293  0.200131  1.0
# m_jlv                     0.083894  0.115426  1.0
# m_bb                      0.068268  0.090682  1.0
# m_wbb                     0.091743  0.119146  1.0
# m_wwbb                    0.091813  0.124884  1.0

# %%
x = higgs_data.drop('class_label', axis=1)
y = higgs_data['class_label']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Assuming X_train and y_train are your features and labels
gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
gb_clf.score(x_test, y_test)
# Out:
# 0.7115

# %%
# calculate roc auc score
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, gb_clf.predict(x_test))
# Out:
# 0.7099406166497086

# %%
from xgboost import XGBClassifier, plot_tree

xgb_clf = XGBClassifier()
xgb_clf.fit(x_train, y_train)

xgb_clf.score(x_test, y_test)
# Out:
# 0.7164375

# %%
xgb_clf_pred = xgb_clf.predict(x_test)
roc_auc_score(y_test, xgb_clf_pred)
# Out:
# 0.7148139086137806

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_test, xgb_clf_pred))
print(classification_report(y_test, xgb_clf_pred))
# Out:
# [[5181 2380]
#  [2157 6282]]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.69      0.70      7561
#          1.0       0.73      0.74      0.73      8439
#
#     accuracy                           0.72     16000
#    macro avg       0.72      0.71      0.72     16000
# weighted avg       0.72      0.72      0.72     16000

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(100, 100))
plot_tree(xgb_clf, ax=ax)
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Create a decision tree classifier object
dt_clf = DecisionTreeClassifier(random_state=0)

# Create an AdaBoost classifier object
# adb_clf = AdaBoostClassifier(base_estimator=dt_clf, random_state=0)

# Train AdaBoost classifier
# adb_clf.fit(x_train, y_train)
dt_clf.fit(x_train, y_train)

# Evaluate the AdaBoost classifier
# adb_score = adb_clf.score(x_test, y_test)
adb_score = dt_clf.score(x_test, y_test)

# Print the score
print(f"dt_clf Classifier Score: {adb_score}")

# Calculate and print the ROC AUC score
dt_clf_roc_auc = roc_auc_score(y_test, dt_clf.predict(x_test))
print(f"dt_clf Classifier ROC AUC Score: {dt_clf_roc_auc}")

# Print the confusion matrix and classification report
dt_clf_pred = dt_clf.predict(x_test)
print(confusion_matrix(y_test, dt_clf_pred))
print(classification_report(y_test, dt_clf_pred))
# Out:
# dt_clf Classifier Score: 0.618
# dt_clf Classifier ROC AUC Score: 0.6167567809935917
# [[4492 3069]
#  [3043 5396]]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.59      0.60      7561
#          1.0       0.64      0.64      0.64      8439
#
#     accuracy                           0.62     16000
#    macro avg       0.62      0.62      0.62     16000
# weighted avg       0.62      0.62      0.62     16000
